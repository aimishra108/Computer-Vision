# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
cars=cv2.imread("DATA/Car_1.jpg")
cars=cv2.cvtColor(cars,cv2.COLOR_BGR2RGB)
# cars=cv2.resize(cars,(8000,8000))
plt.imshow(cars)

# %%
lic_1=cv2.imread("DATA/Lic_1.jpg")
lic_1=cv2.cvtColor(lic_1,cv2.COLOR_BGR2RGB)
plt.imshow(lic_1)

# %%
height,width,color=lic_1.shape

# %%
width
# Out:
# 100

# %%
height
# Out:
# 37

# %%
color
# Out:
# 3

# %%
# All the template-matching methods
methods = ['cv2.TM_CCOEFF', 'cv2.TM_CCOEFF_NORMED', 'cv2.TM_CCORR','cv2.TM_CCORR_NORMED', 'cv2.TM_SQDIFF', 'cv2.TM_SQDIFF_NORMED']

# %%
for m in methods:
    full_copy=cars.copy()
    
    method=eval(m)
    res=cv2.matchTemplate(full_copy,lic_1,method)
    
    min_val,max_val,min_loc,max_loc=cv2.minMaxLoc(res)
    
    if m in[cv2.TM_SQDIFF, cv2.TM_SQDIFF_NORMED]:
        top_left=min_loc
    else:
        top_left=max_loc
        
    bottom_right=(top_left[0]+width,top_left[1]+height)
    
    cv2.rectangle(full_copy,top_left,bottom_right,255,thickness=10)
    
    plt.subplot(121)
    plt.imshow(res)
    plt.title("Template Matching")
    
    
    plt.subplot(122)
    plt.imshow(full_copy)
    plt.title("Detected Point")
    plt.suptitle(m)
    
    plt.show()
    print('\n')
    print('\n')
